# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print ("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 3.3.1

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# 1. O histograma nao aproveita bem as faixas de cor, uma vez que uma cor varia de intensidade de 0 a 255 e são utilizados apenas até intensidade de 8 a 58. Dessa forma a imagem poderia ter tons mais bem definidos e ser menos escura(decorrente das intensidade se encontrarem apenas nos valores possíveis mais baixos.

# %%
#cdf
max = np.amax(rintin_gray)
min = np.amin(rintin_gray)

# %%
rintin_better = ( rintin_gray )*(255/max)

# %%
hist,bins = np.histogram(rintin_better.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_better.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
plt.imshow(rintin_better, cmap="Greys_r", vmin=0, vmax=255)

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %%
box_battery = cv2.imread("hall_box_battery1.jpg")

# %%
box_battery_rgb = cv2.cvtColor(box_battery, cv2.COLOR_BGR2RGB)
hist,bins = np.histogram(box_battery_rgb.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(box_battery_rgb.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
#Fazendo "Manualmente"
box_battery_rgb = cv2.cvtColor(box_battery, cv2.COLOR_BGR2RGB)
for line in box_battery_rgb:
    for p in line:
        if p[0]>140 and p[1]<130 and p[2]<130:
            p[0]=255
            p[1]=255
            p[2]=255
        

print("foi")
# Out:
# foi

# %%
plt.imshow(box_battery_rgb, vmin=0, vmax=255)
